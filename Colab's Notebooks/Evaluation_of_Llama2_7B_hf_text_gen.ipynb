# %% [markdown]
# # Install Required Libraries

# %%
# !pip install -q -U bitsandbytes
# !pip install -q -U git+https://github.com/huggingface/transformers.git
# !pip install -q -U git+https://github.com/huggingface/peft.git
# !pip install -q -U git+https://github.com/huggingface/accelerate.git
# !pip install -q datasets einops

# %% [markdown]
# # Log in to Hugging Face

# %%
from huggingface_hub import notebook_login

notebook_login()

# %% [markdown]
# # Load & Quantize the model

# %%
# import torch
# from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig

# model_id = "Hieu-Pham/Llama-2-7B-QLoRA-cooking-300-merged"

# bnb_config = BitsAndBytesConfig(
#     load_in_4bit=True,
#     bnb_4bit_use_double_quant=True,
#     bnb_4bit_quant_type="nf4",
#     bnb_4bit_compute_dtype=torch.bfloat16
# )

# tokenizer = AutoTokenizer.from_pretrained(model_id)
# tokenizer.pad_token = tokenizer.eos_token
# model = AutoModelForCausalLM.from_pretrained(model_id, quantization_config=bnb_config, device_map={"":0})

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM

model_id = "Hieu-Pham/Llama2-7B-IA3-cooking-text-gen-merged"

tokenizer = AutoTokenizer.from_pretrained(model_id)
tokenizer.pad_token = tokenizer.eos_token
model = AutoModelForCausalLM.from_pretrained(model_id, device_map={"":0}, torch_dtype=torch.bfloat16)

# %% [markdown]
# # Load and preprocessing the dataset

# %%
from datasets import load_dataset

# Load test dataset
test_data = load_dataset("Hieu-Pham/cooking_squad_splitted", split='test')

# Preprocessing test and validation dataset
def group_test_data(dataset):

    grouped = []
    ref_answers = []

    for row in dataset:
      #input = "Question: " + row['question'] + " Context: " + row['context'] + " Answer: "
      input = "Question: " + row['question'] + " Context: " + row['context'] + " Answer: "

      grouped.append(input)

      ref_answer = row['answers']['text']
      ref_answers.append(ref_answer)

    return grouped, ref_answers

# Test dataset
output_column, reference = group_test_data(test_data)
test_data = test_data.add_column('Outputs', output_column)
# Out:
# Downloading data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/1.25M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/157k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/155k [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]

# %%
from transformers import pipeline
from transformers import StoppingCriteria, StoppingCriteriaList

stop_token_ids = tokenizer.convert_tokens_to_ids(["\n", "#", "\\", "`", "###", "##", "Question", "Comment"])

# define custom stopping criteria object
class StopOnTokens(StoppingCriteria):
    def __call__(self, input_ids: torch.LongTensor, scores: torch.FloatTensor, **kwargs) -> bool:
        for stop_id in stop_token_ids:
            if input_ids[0][-1] == stop_id:
                return True
        return False

stopping_criteria = StoppingCriteriaList([StopOnTokens()])

pipe = pipeline(
    task="text-generation",
    model=model,
    tokenizer=tokenizer,
    return_full_text=False,
    stopping_criteria=stopping_criteria,
    temperature=0.1,  # 'randomness' of outputs, 0.0 is the min and 1.0 the max
    top_p=0.15,  # select from top tokens whose probability add up to 15%
    top_k=0,  # select from top 0 tokens (because zero, relies on top_p)
    max_new_tokens=100,  # max number of tokens to generate in the output
    repetition_penalty=1.1 # without this output begins repeating
)

test = "Question: How many eggs are there in the basket? Context: There are 2 eggs in the basket. Answer: "

outputs = []

for out in pipe(test_data['Outputs']):
  outputs.append(out)

# %%
outputs

# %%
import pandas as pd

prediction = []

for row in outputs:
  prediction.append(row[0]['generated_text'])

# %%
replace_list = ['\\', '\n', '`', '#', 'Comment']

formatted_prediction = []

for row in prediction:
  for replace in replace_list:
    row = row.replace(replace, '')

  formatted_prediction.append(row)

# %%
formatted_prediction
# Out:
# ['3 1/2 c. (8 oz.) large shells (uncooked)',
#  '3 hours',
#  '4 (1 oz.) slices Canadian bacon',
#  '1/2 c.',
#  '15 minutes',
#  '3 eggs, 1 c. oil, 1 1/2 c. honey, 2 tsp. vanilla, 2 c. shredded zucchini, 1 c. unsweetened crushed pineapple, 1 c. raisins, 2 c. whole wheat flour, 3/4 c. unbleached flour, 2 tsp. soda, 1 tsp. salt, ',
#  '1 (14 oz.) can evaporated skim milk, 1/2 c. vinegar, 1 envelope (about 1 1/2 oz.) onion soup mix, 1/3 c. catsup, 1/2 tsp. Worcestershire sauce, 1/4 tsp. red pepper sauce',
#  '1. Mix all ingredients except the ketchup.2. Put mixture in a large iron skillet.3. Spoon ketchup over top.4. Bake, uncovered, in a 350° oven for 1 hour and 15 minutes.',
#  '2 lb. ground meat',
#  '3 layers',
#  '1/3 cup of oil',
#  '8 minutes',
#  '8 minutes',
#  '1. Cook all ingredients in 1 1/2-quart saucepan over medium heat for 4 to 5 minutes, stirring vigorously, until mixture forms a ball.2. Remove dough from saucepan and let stand on counter 5 minutes.3. Knead dough about 30 seconds or until smooth and blended. Cool completely.4. Store in airtight container in refrigerator',
#  '1 (No. 2 1/2) can kraut',
#  '1. Put in unbaked pie shell.2. Top apples with 2 tablespoons margarine with crust.3. Brush milk on top of crust and sprinkle with sugar.4. Bake on bottom shelf at 400° for 45 minutes.',
#  '30 minutes',
#  '8 eggs3. Combine baking soda and buttermilk; add to creamed mixture alternately with flour, beginning and ending with flour.4. Stir in 1 1/2 cups of the chocolate morsels. Pour into two greased and floured 9x5x3-inch loaf pans.5. Bake at 350° for 60 minutes or until a wooden',
#  '1 can small shrimp, 1 (8 oz.) pkg. cream cheese, 1/4 c. Catalina salad dressing, parsley flakes',
#  '35-40 minutes',
#  '2 1/4 to 2 1/2 hours',
#  '45 minutes',
#  '1 Tbsp. milk',
#  '1) To make it easier to mix the ingredients together. 2) To make it easier to spread the mixture out on the pan. 3) To make it easier to cut the bars after they have cooled.',
#  '1/4 cup',
#  '24 hours',
#  '15 minutes',
#  '30 minutes',
#  '2 or 3 pecans at a time',
#  '2 cups of chicken',
#  '350 degrees Fahrenheit for one hour.',
#  '1 lb. ground beef + 1/2 lb. ground pork = 1.5 lbs. of meat',
#  '1/2 c. buttermilk',
#  '1 cup',
#  '2 loaves',
#  '1 pkg. cornbread mix',
#  '1 1/2 cups of flour',
#  '375° for 20-25 min.',
#  '1. Brown ribs in shortening; add onion, salt, pepper and water. Cover and simmer for 1 hour over low heat.2. Add sauerkraut; cover and cook for 20 minutes.',
#  '1/4 cup of salad oil should be used to cook the onions and green pepper.',
#  '1. While rice is cooking, cut steak into 1/4-inch strips. Sprinkle meat with paprika and allow to stand while preparing other ingredients.2. Melt butter or margarine in a skillet over medium heat; add garlic and sauté until tender. Add broth, green onions, peppers, and cornstarch; bring to boiling. Reduce heat; simmer for ',
#  '30 minutes2. Drain onions, reserving liquid. Beat eggs slightly; add water, oil, lemon juice, flour, baking powder, salt, and cayenne pepper. Stir until smooth. Answer: 30 seconds3. Heat oil in a deep-fat fryer or heavy saucepan to 375°F. Answer: 375°F4',
#  '15 minutes',
#  '5. Press down on cookie sheet with a glass dipped in sugar.',
#  '40 minutes',
#  '1 cup of milk',
#  '350° Fahrenheit',
#  '4. Add 3/4 cup water, stirring until mixture boils.',
#  '6 servings',
#  '1 1/2 cups uncooked whole wheat shells or spirals (1 1/2 cups cooked).',
#  '20 to 25 minutes',
#  '20 minutes',
#  '1. Brown beef in margarine; add garlic and saute for 2 to 3 minutes.2. Add flour to meat; stir.3. Add Guiness and stir well to remove any lumps.4. Add remaining ingredients, stirring very frequently, to avoid sticking.5. Stew is done when potatoes and carrots are tender.',
#  '1. Mix dry ingredients; whip eggs and oil together and add remaining ingredients and stir to mix well.2. Pour into a greased and floured 9 x 13-inch pan and bake at 350° for 40 minutes.',
#  '8 to 12 hours',
#  '1 3/4 c. flour1/3 c. sugar2 1/2 tsp. baking powder1/2 tsp. salt1 c. blueberries3/4 c. milk1 egg1/3 c. melted butter1. In a large bowl, combine flour, sugar, baking powder and salt. Stir in blueberries.2. Add milk',
#  '325 degrees Fahrenheit, 10 minutes.',
#  '1 cup',
#  '1/2 stick butter',
#  '5. Add milk to make a thick sauce.',
#  '6 minutes',
#  '20 minutes',
#  '5 minutes',
#  '1. Make white or yellow cake mix and bake according to package directions in a 9 x 13-inch sheet pan.2. Immediately pour the Eagle Brand milk over hot cake.3. Let sit until cake is warm.4. Pour the cream of coconut over cake.5. Sprinkle with coconut.',
#  '1. Mix chicken, soup, celery, onions, water chestnuts and mayonnaise.2. Add 1 cup of cornflakes and mix.3. Pour into buttered casserole dish.4. Mix the rest of cornflakes with butter and spread on top.5. Bake at 325° for 35 minutes.',
#  '3 lemons',
#  '8-10 minutes',
#  '1 hour at 350°.',
#  '25 to 30 minutes',
#  '1 stick of butter',
#  '1 lb. of spaghetti',
#  '3 to 4 c. cooked, cut up chicken',
#  '1/8 cup of each ingredient',
#  '1 1/4 cups water',
#  '1 cup',
#  '1 hour and 35 to 40 minutes.',
#  '450 degrees for 10 minutes.',
#  '4-6 hours',
#  '350 degrees Fahrenheit for one hour.',
#  '12-15 minutes',
#  '1 3/4 sticks butter or margarine',
#  '1 1/2 hours',
#  '25-30 minutes',
#  '30 to 35 minutes at 325°.',
#  '3 dozen.',
#  '3 or 4 seconds',
#  '30 to 35 minutes',
#  '5 minutes per side.',
#  '16 oz.',
#  '30 minutes',
#  '1. Drain beans.2. Mix all ingredients together, except Fritos. Add Fritos just before serving.',
#  '1. In a 5-quart pan, add 3 quarts of water and all ingredients, except garlic, olive oil and paprika.2. (Mash garlic; mix with paprika and olive oil and add to the beans after beans are tender.) Add water as needed.3. Serves 6.',
#  ' Yes, you can add any vegetable you want.Question',
#  '4 cans',
#  '16 servings',
#  '300 degrees Fahrenheit',
#  '1. Scrape and cut carrots into small pieces or chunks.2. Cook and drain; salt.3. Drain pineapple.4. Use 1/2 cup pineapple juice, cornstarch, oleo and sugar and cook until thick.5. Add carrots and pineapple to sauce and simmer 10 minutes.6. Better if made a day ahead.',
#  '1/4 cup of oil is needed for this recipe.',
#  '1 pack',
#  '1 hour and 20 minutes',
#  '1/2 c. mayonnaise',
#  '20 minutes at 375°',
#  '15 minutes',
#  '1 lb. boneless beef sirloin steak',
#  '1 hour',
#  '3 Tbsp salt',
#  '1. Measure Rice Krispies cereal; crush to 2 cups.2. Place in shallow dish.3. Stir in paprika.4. Set aside.5. In large bowl, beat egg until foamy.6. Gradually add milk, stirring constantly.7. Add flour, salt, pepper, and poultry seasoning; mix well.8.',
#  '1/2 c. mayonnaise, 1/2 c. Parmesan cheese, dash of Worcestershire sauce, dash of Tabasco sauce, 1 tsp. horseradish, party rye bread, thinly sliced onion rings',
#  '5 slices',
#  '1/2 cup of each ingredient.',
#  '400°F, 15 min.',
#  '1. Grease Bundt or tube pan.2. Mix together 3/4 cup sugar and 1 1/2 teaspoons cinnamon.3. Cut each biscuit in fourths, using scissors to do this.4. Shake pieces from one can at a time in the sugar/cinnamon mixture.5. Place these into cake pan.6. Melt margarine,',
#  ' Fritos or Doritos',
#  '1 hour',
#  '10 minutes',
#  '1 lb. stew meat, 1 pkg. Lipton onion soup mix, 2 cans cream of mushroom soup',
#  '325° Fahrenheit, 15 - 20 minutes',
#  '1 cup of crushed Oreo cookies',
#  '10 to 15 minutesAnswer: 10 to 15 minutes',
#  '6 cups',
#  '1. The mixture will be a thick liquid.2. The mixture will be a thick liquid.3. The mixture will be a thick liquid.4. The mixture will be a thick liquid.',
#  '1 1/2 pounds hamburger',
#  '6 servings',
#  '1 cup',
#  '1. Combine graham cracker crumbs and 1 stick melted oleo.2. Pat in bottom of pan. Beat 2 cups powdered sugar, 2 sticks oleo and eggs 15 minutes.3. Pour over crumb mixture. Slice layer of bananas on this. Spread drained pineapple, then Cool Whip on top.4. Sprinkle with nuts and cher',
#  '2 Tbsp.',
#  '30 minutes',
#  '1/4 cup sherry',
#  '1 cup of water',
#  '10 minutes at 425°, then 25 minutes at 350°.',
#  '15 to 18 minutes',
#  '4 servings',
#  '350°F for 45 minutes to 1 hour.',
#  '2 quarts and 1 pint',
#  '4 servings',
#  '30 minutes',
#  '1. Combine whipped cream and powdered sugar.2. Spread over crust when cooled.3. Let set 3 to 4 hours.4. When ready to serve, top with sweetened fresh fruit.',
#  '1 hour',
#  '8 hours3. Preheat oven to 350°F. Place turkey in a roasting pan. Bake until juices run clear when pierced with a fork, about 1 hour per pound. Answer: 1 hour per pound4. Remove from oven and let stand for 10 minutes before carving. Serve with rice and steamed vegetables. Answer: Rice and steamed vegetables',
#  '1. Cream butter2. and3. sugar.4. Add eggs, one at a time, and mix well.5. Add buttermilk.6. Add flour, 1 cup at a time, mixing well. Add vanilla.7. For8. layer cake bake at 350° for 35 to 40 minutes. For sheet9. cake10',
#  '6 to 8 minutes',
#  '3/4 cup of 7-Up should be added to the cake batter.',
#  '20 minutes at 350 degrees Fahrenheit.',
#  '5 to 7 minutes',
#  '5 minutes',
#  '1. Sprinkle dates with baking soda and cover with hot water.',
#  '1/2 cup of brown sugar',
#  '1. You could add more or less water depending on how thick you want it. 2. You could add more or less salt depending on how salty you like it. 3. You could add more or less celery salt depending on how much flavor you want.',
#  '3 minutes',
#  '1 hour',
#  '3. Put into pan.Answer: 3. Put into pan.',
#  '1/2 cup of cheddar cheese is needed for this recipe.',
#  '1 1/2 c. self-rising flour',
#  '5 or 6 chicken breasts, 1 can cream of chicken soup, 1 c. sour cream, 1 Tbsp. lemon juice, 1/4 box crackers (1 pack of 4 pack box), 1/2 stick oleo, poppy seed',
#  '1. Preheat oven to 350°.2. Grease and flour sheet cake pan (9 x 13-inch).3. Sprinkle nuts and coconut in pan.4. Spread to cover. Mix cake according to package directions.5. Pour evenly over nuts and coconut, but do not stir.6. Melt margarine and cream cheese in pan',
#  '1 1/2 tbsp. cornstarch, 1/2 c. sugar, 1 c. crushed pineapple, 3/4 c. water, 1 tbsp. lemon juice',
#  '35 minutes',
#  "1. Mix dry pudding mix with pumpkin. Fold in Cool Whip. Add spices and Sweet 'N Low.",
#  '1. Melt almond bark with package directions. Stir in all other ingredients. Drop and shape on waxed paper.',
#  '4 minutes',
#  '6 servings',
#  '1 cup sour cream',
#  '350 degrees Fahrenheit for 10-15 minutes.',
#  '3. Cook over low heat 15 minutes, stirring occasionally.',
#  '8 dozen',
#  '1 hour',
#  '1 minute',
#  '5. Freeze.',
#  '1/2 cup liquid',
#  '1 hour and 15 minutes',
#  '375°',
#  '6 calories per tablespoon',
#  '1 hour',
#  '3 cups',
#  '45 minutes',
#  '1. In saucepan, melt oleo; add cocoa.2. Combine remaining ingredients and add oleo-cocoa mixture.3. Bake in 9 x 13-inch pan for 30 minutes at 350°.4. While still hot, punch holes in cake. Spread on cake, 1/2 cup peanut butter mixed with 1 1/',
#  '1 hour',
#  '3 lb. ground beef, 2 c. chopped onions, 1 c. chopped celery, 1 c. chopped green bell pepper, 3 Tbsp. cumin seed, 3 cloves garlic, minced, 4 tsp. chili powder, salt and pepper to taste, 8 oz. Velveeta cheese, shredded, 1 (10 oz.) can Ro-T',
#  '1. Mix all ingredients into a bowl. 2. Pour onto floured surface. Cover with flour and shape into a ball.',
#  '1 hour',
#  '45 minutes',
#  '3 minutes',
#  '20 minutes',
#  '6 to 8 servings',
#  '1 cup',
#  '4 to 6 chicken thighs or other chicken parts',
#  '5 slices',
#  '1/2 cup brown sugar',
#  '30 minutes',
#  '4 cups (1 quart)',
#  '5 to 6',
#  '3 Tbsp. white vinegar, 1 tsp. salt, 1/8 tsp. white pepper',
#  '4 cans of soup',
#  '1. Boil all ingredients, except eggs and beets in a saucepan. Add the beets and simmer for several minutes.2. Cool to just warm and add shelled, boiled eggs.3. When cool, keep in refrigerator.',
#  '10-15 minutes',
#  '1 c. crushed or chopped fresh strawberries or 1 (10 oz.) pkg. frozen strawberries, drained',
#  '30 minutes',
#  '3-5 hours',
#  '1 hour 15 minutes',
#  '1 (12 oz.) can tomato paste = 12 oz.',
#  '20 chicken wings',
#  '1. Brown meat and seasoning in skillet.2. Drain off fat.3. Add tomato paste; blend.4. Turn mixture out on crust.5. Top with cheese. Bake at 375° for 10 to 15 minutes.',
#  '2 eggs',
#  '4 slices Mozzarella cheese',
#  '1 pizza',
#  '20 minutes',
#  '1 teaspoon of tea mix to 1 cup of hot water.',
#  '1 cup of flour',
#  '2 well-greased loaf pans should be used for this recipe.',
#  '45 minutes',
#  '325 degrees FahrenheitAnswer: 325 degrees Fahrenheit',
#  '10 (1/8-inch) pork loin cutlets (about 1 lb.)',
#  ' The cheese melts and adds flavor to the casserole.',
#  '1 hour and 15 minutes',
#  '1/4 lb. Provolone cheese',
#  '60 to 70 minutes',
#  '2 loaves frozen bread, softened',
#  '3. Mix well.',
#  '5 minutes',
#  '45 minutes',
#  '1 hour',
#  '1. Cool.',
#  '3/4 cup liquid from pineapple plus water (if needed)',
#  '1 cup',
#  '1. Melt butter in frying pan.']

# %%
df = pd.DataFrame(formatted_prediction)
df.to_csv('prediction.csv')

# %%
reference

# %%
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.metrics import f1_score, accuracy_score

binarizer = MultiLabelBinarizer()

binarizer.fit(reference)

# F1 Score
f1_score(binarizer.transform(reference),
         binarizer.transform(formatted_prediction),
         average='samples')

# Accuracy Score
accuracy_score(reference, formatted_prediction)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['+', '=', 'Q', 'V', 'é'] will be ignored
#   warnings.warn(
# 0.7141221837959175
